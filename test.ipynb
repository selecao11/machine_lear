# %%
import pandas as pd
import os

#https://qiita.com/luohao0404/items/7135b2b96f9b0b196bf3
#カラムを正規表現で検索するなら、matchメソッドとlocメソッドを使うと簡単な件
#https://pon3-blog.com/?p=291
path1 = "C:\\anaconda3\\envs\\machine_lear\\machine_lear\\"
path2 = "財政力指数ランキングtest.txt"
w_path = os.path.join(path1, path2)
df = pd.read_csv(w_path,sep='\t')
#print(df.query('東京都.match("*>")'))
print(df[df['東京都'].str.contains('>')])
#print(df)
path3 = "test2.txt"
w2_path = os.path.join(path1, path2)
#df.to_csv(w2_path)
k=1
print(df)
# Out:
#      Unnamed: 0       東京都           武蔵野市  1.52    （1位）   66\t478\t882千円  \
# 126         126      >静岡県            掛川市  0.90  （125位）   47\t193\t362千円
# 128         128      >静岡県        2221焼津市  0.90  （125位）   54\t439\t578千円
# 132         132      >静岡県   221007/">静岡市  0.90  （125位）  312\t971\t223千円
# 133         133  35/">山口県   352071/">下松市  0.89  （135位）   23\t177\t572千円
# 136         136      >静岡県   222160/">袋井市  0.89  （135位）   34\t113\t628千円
# ..          ...       ...            ...   ...     ...              ...
# 809         809  01/">北海道   012181/">赤平市  0.21  （811位）   11\t081\t347千円
# 810         810  01/">北海道   012220/">三笠市  0.20  （812位）   11\t020\t839千円
# 811         811  01/">北海道   012092/">夕張市  0.20  （812位）   11\t308\t431千円
# 812         812  42/">長崎県   422096/">対馬市  0.19  （814位）   32\t497\t322千円
# 813         813  01/">北海道  012271/">歌志内市  0.11  （815位）    4\t628\t322千円
#
#      （171位）  146\t399人  （189位）   9\t636\t000円  （107位）
# ...
